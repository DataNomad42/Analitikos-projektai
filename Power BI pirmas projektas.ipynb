# %% [markdown]
# Projekto duomenys:
# Klinikos duomenys ligoninėje, veikla ligoninėje gydytoju pacientu duomenys pateikti.
# desember 2025 january 2026 2 montshs of data
# kas daktarai
# kas pacientai
# calaneder table
# is visos 3 lenteles duomenu sitame faile

# %% [markdown]
# Metodologija
# Tikslas pdaryti reporrta
# atskirti kurie paicentia buvo 1 diena kurie buvo ilgiau

# %% [markdown]
# kai kurie pacientia turi folowup kai kurie turi tik viena vizita.

# %% [markdown]
# calender 1 day is 1 row,
# how are thing in difrent weaks, is there fisrence on weeekdays and on weakends.

# %% [markdown]
# Data cannects: all tre tables connect throu patient table,

# %% [markdown]
# in date when cme in
# out date kada isjeo is ligonines
# glaima paialdoamai paskaiciuoti kanors sus pacientu amziumi ir pan. pagal DOB date of birth

# %% [markdown]
# 35 doctors in total
# 6 departments is viso:

# %% [markdown]
# .................................

# %% [markdown]
# Buisenes questions:
# how many patietns the hospital had in this period?
# what is theyr trend?
# who are our patients?
# gender brakedown, age grouping, old or young,
# where they live? map where are they from
# Who refered them? by doctors or by themselfs or other hospitals?
# Departments
# how buisy diffrent departments
# how buisy that are buisey,
# some doctor are only getting only some paiteints a day athers ahav alllot of paiteints a day
# in patient - left on dfirent thay thent they came in
# out patieint letf on the sem day
# koks procentas pacientu gavo follow up?

# %% [markdown]
# Paties atlikta dalis:

# %% [markdown]
# Failo šaltinis: https://github.com/chandoo-org/Power-BI/blob/9600039d931ad949c2798563e029d968859fb599/hospital%20report/clinic_report_blank.pbix
# Parengta vadovaujantis: https://www.youtube.com/watch?v=bokH-VVB1fs
